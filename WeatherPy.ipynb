# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#Import API key
from api_keys import weather_api_key

#Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Output File (CSV)
output_data_file = "output_data/cities.csv"

#Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

#Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#Identify closest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0],lat_lng[1]).country_code
    
#If city is unique, add to cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())

#Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %%
#Create a dataframe to store the data
city_temp = pd.DataFrame({'City': cities, 'Cloudiness': "", 'Country': countries, 'Date': "",
                            'Humidity': "", 'Lat': "", 'Lng': "", 'Max Temp': "", 'Wind Speed': ""})


#Preview the dataframe
#city_temp.head(50)
city_temp.head()
# Out:
#             City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0       thompson                 CA
# 1          erzin                 RU
# 2  mar del plata                 AR
# 3          kapaa                 US
# 4          tiksi                 RU

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Variables used to track responses
record = 0
set = 1

params = {"weather_api_key": weather_api_key}

url =  "http://api.openweathermap.org/data/2.5/weather?q="
print('''
Beginning Data Retrieval     
-----------------------------''')
#iterates through each row in city_temp data frame
for index, row in city_temp.iterrows(): 

#Query URL; updates City & Country variables from city_temp data frame each row iteration
    updated_url = url + row['City'] + ',' + row['Country'] + '&units=imperial'+'&APPID=' + weather_api_key

#Pulls data from URL/converts to JSON format  
    response = requests.get(updated_url).json()
        
    try:
        
#Prints retrieval information
        print(f'Processing Record {record} of Set {set} | {response["name"]}')
        
#Inputs retrieved API data into city_temp data frame
        city_temp.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_temp.loc[index, 'Date'] = response['dt']
        city_temp.loc[index, 'Humidity'] = response['main']['humidity']
        city_temp.loc[index, 'Lat'] = response['coord']['lat']
        city_temp.loc[index, 'Lng'] = response['coord']['lon']
        city_temp.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_temp.loc[index, 'Wind Speed'] = response['wind']['speed']
        
#Increases the record count by one each iteration
        record += 1

#Skips records with either key or index error; prints notification for each error identified
    except (KeyError, IndexError):
        print("City not found. Skipping...")   

#Increases set number by 1 when record number is greater than 50, record number is reset to 0
    if record > 50:
        set += 1
        record = 0

#Notification that all data is retrieved
print('''
-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | Thompson
# Processing Record 1 of Set 1 | Erzin
# Processing Record 2 of Set 1 | Mar del Plata
# Processing Record 3 of Set 1 | Kapaa
# Processing Record 4 of Set 1 | Tiksi
# Processing Record 5 of Set 1 | Chokurdakh
# Processing Record 6 of Set 1 | Tuatapere
# Processing Record 7 of Set 1 | Oron
# Processing Record 8 of Set 1 | Buctzotz
# Processing Record 9 of Set 1 | Rundu
# Processing Record 10 of Set 1 | Ribeira Grande
# Processing Record 11 of Set 1 | Caçu
# Processing Record 12 of Set 1 | Puerto Ayora
# Processing Record 13 of Set 1 | Punta Arenas
# Processing Record 14 of Set 1 | Jamestown
# City not found. Skipping...
# Processing Record 15 of Set 1 | Longyearbyen
# Processing Record 16 of Set 1 | Bethel
# Processing Record 17 of Set 1 | Ushuaia
# Processing Record 18 of Set 1 | Villazón
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 1 | Ahipara
# Processing Record 20 of Set 1 | Coyhaique
# Processing Record 21 of Set 1 | Port Elizabeth
# Processing Record 22 of Set 1 | Torbay
# Processing Record 23 of Set 1 | Albany
# Processing Record 24 of Set 1 | Cravo Norte
# Processing Record 25 of Set 1 | Cabo San Lucas
# Processing Record 26 of Set 1 | Barrow
# Processing Record 27 of Set 1 | Port Alfred
# Processing Record 28 of Set 1 | Dikson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 1 | Nouadhibou
# Processing Record 30 of Set 1 | Busselton
# Processing Record 31 of Set 1 | Svetlogorsk
# Processing Record 32 of Set 1 | Bluff
# Processing Record 33 of Set 1 | Rikitea
# Processing Record 34 of Set 1 | Kenai
# Processing Record 35 of Set 1 | East London
# Processing Record 36 of Set 1 | Puerto Baquerizo Moreno
# Processing Record 37 of Set 1 | Atuona
# Processing Record 38 of Set 1 | Vanimo
# Processing Record 39 of Set 1 | Bathsheba
# Processing Record 40 of Set 1 | Los Llanos de Aridane
# Processing Record 41 of Set 1 | Katsuura
# Processing Record 42 of Set 1 | Ponta do Sol
# Processing Record 43 of Set 1 | Te Anau
# Processing Record 44 of Set 1 | Tuktoyaktuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 1 | Vaini
# Processing Record 46 of Set 1 | Grão Mogol
# Processing Record 47 of Set 1 | Ankpa
# Processing Record 48 of Set 1 | Qaanaaq
# Processing Record 49 of Set 1 | Husavik
# Processing Record 50 of Set 1 | Mahébourg
# Processing Record 0 of Set 2 | Cape Town
# Processing Record 1 of Set 2 | Lázaro Cárdenas
# City not found. Skipping...
# Processing Record 2 of Set 2 | Buinsk
# Processing Record 3 of Set 2 | Georgetown
# Processing Record 4 of Set 2 | Cockburn Town
# Processing Record 5 of Set 2 | Pacifica
# Processing Record 6 of Set 2 | Cayenne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 2 | Norman Wells
# Processing Record 8 of Set 2 | Bambous Virieux
# Processing Record 9 of Set 2 | Hobart
# Processing Record 10 of Set 2 | Naze
# Processing Record 11 of Set 2 | Tame
# Processing Record 12 of Set 2 | Arraial do Cabo
# Processing Record 13 of Set 2 | Carnarvon
# Processing Record 14 of Set 2 | Nikolskoye
# Processing Record 15 of Set 2 | Hermanus
# Processing Record 16 of Set 2 | Bonthe
# Processing Record 17 of Set 2 | Tocopilla
# Processing Record 18 of Set 2 | Kiama
# Processing Record 19 of Set 2 | Kysyl-Syr
# Processing Record 20 of Set 2 | Geraldton
# Processing Record 21 of Set 2 | Salinópolis
# Processing Record 22 of Set 2 | New Norfolk
# Processing Record 23 of Set 2 | Key Largo
# Processing Record 24 of Set 2 | Tokur
# Processing Record 25 of Set 2 | General Pico
# Processing Record 26 of Set 2 | Esperance
# Processing Record 27 of Set 2 | Butaritari
# Processing Record 28 of Set 2 | Linfen
# Processing Record 29 of Set 2 | Tomatlán
# Processing Record 30 of Set 2 | Vestmanna
# Processing Record 31 of Set 2 | Port Hardy
# Processing Record 32 of Set 2 | Ciudad del Carmen
# Processing Record 33 of Set 2 | Miragoâne
# Processing Record 34 of Set 2 | Ekibastuz
# Processing Record 35 of Set 2 | Ugoofaaru
# Processing Record 36 of Set 2 | Bonavista
# City not found. Skipping...
# Processing Record 37 of Set 2 | Yellowknife
# Processing Record 38 of Set 2 | Camacha
# Processing Record 39 of Set 2 | Bengkulu
# Processing Record 40 of Set 2 | Dingle
# Processing Record 7 of Set 4 | Chapais
# Processing Record 8 of Set 4 | Turka
# Processing Record 9 of Set 4 | Oranjemund
# Processing Record 10 of Set 4 | Salinas
# Processing Record 11 of Set 4 | College
# Processing Record 12 of Set 4 | Humaitá
# Processing Record 13 of Set 4 | Saskylakh
# City not found. Skipping...
# Processing Record 14 of Set 4 | Algeciras
# Processing Record 15 of Set 4 | Meulaboh
# Processing Record 16 of Set 4 | Porto Empedocle
# Processing Record 17 of Set 4 | Vallenar
# Processing Record 18 of Set 4 | Desaguadero
# Processing Record 19 of Set 4 | Ha Giang
# Processing Record 20 of Set 4 | Lüderitz
# Processing Record 21 of Set 4 | Saint-Augustin
# Processing Record 22 of Set 4 | Kulhudhuffushi
# Processing Record 23 of Set 4 | San Quintín
# Processing Record 24 of Set 4 | Seoul
# Processing Record 25 of Set 4 | Northam
# Processing Record 26 of Set 4 | Soyaniquilpan
# Processing Record 27 of Set 4 | Lafia
# Processing Record 28 of Set 4 | Konya Province
# City not found. Skipping...
# Processing Record 29 of Set 4 | Nizhniy Kuranakh
# Processing Record 30 of Set 4 | Bodden Town
# Processing Record 31 of Set 4 | Moose Factory
# Processing Record 32 of Set 4 | Berlevåg
# City not found. Skipping...
# Processing Record 33 of Set 4 | Yar-Sale
# Processing Record 34 of Set 4 | Mogadishu
# Processing Record 35 of Set 4 | Guerrero Negro
# Processing Record 36 of Set 4 | Māngrol
# City not found. Skipping...
# Processing Record 37 of Set 4 | Yulara
# Processing Record 38 of Set 4 | Aswān
# Processing Record 39 of Set 4 | Coquimbo
# Processing Record 40 of Set 4 | Chicama
# Processing Record 41 of Set 4 | Comodoro Rivadavia
# Processing Record 42 of Set 4 | Deniliquin
# Processing Record 43 of Set 4 | Kloulklubed
# City not found. Skipping...
# Processing Record 44 of Set 4 | Fort Nelson
# City not found. Skipping...
# Processing Record 45 of Set 4 | Río Gallegos
# Processing Record 46 of Set 4 | Châteauroux
# City not found. Skipping...
# Processing Record 47 of Set 4 | Hasaki
# Processing Record 48 of Set 4 | Bellegarde-sur-Valserine
# Processing Record 49 of Set 4 | Souillac
# Processing Record 50 of Set 4 | San Patricio
# City not found. Skipping...
# Processing Record 0 of Set 5 | Mehamn
# Processing Record 1 of Set 5 | Chany
# Processing Record 2 of Set 5 | Victoria
# Processing Record 3 of Set 5 | Santa Cruz
# Processing Record 4 of Set 5 | Weatherford
# Processing Record 5 of Set 5 | Touros
# Processing Record 6 of Set 5 | Tautira
# Processing Record 7 of Set 5 | Pucallpa
# Processing Record 8 of Set 5 | Santa Isabel Rio Negro
# Processing Record 9 of Set 5 | Luganville
# Processing Record 10 of Set 5 | San José
# Processing Record 11 of Set 5 | Grand-Santi
# Processing Record 12 of Set 5 | Ambāgarh Chauki
# Processing Record 13 of Set 5 | Puerto Madryn
# Processing Record 14 of Set 5 | Lormi
# Processing Record 15 of Set 5 | Palana
# Processing Record 16 of Set 5 | Mesetas
# Processing Record 17 of Set 5 | Misawa
# Processing Record 18 of Set 5 | Matagami
# Processing Record 19 of Set 5 | Mount Gambier
# Processing Record 20 of Set 5 | Sakakah
# Processing Record 21 of Set 5 | Ondjiva
# Processing Record 22 of Set 5 | Talnakh
# Processing Record 23 of Set 5 | Margate
# Processing Record 24 of Set 5 | Iqaluit
# Processing Record 25 of Set 5 | Saint-Philippe
# Processing Record 26 of Set 5 | Lagoa
# Processing Record 27 of Set 5 | Avarua
# Processing Record 28 of Set 5 | Acaraú
# Processing Record 29 of Set 5 | Vikhorevka
# Processing Record 30 of Set 5 | Almeirim
# Processing Record 31 of Set 5 | Pangnirtung
# Processing Record 32 of Set 5 | Myitkyina
# Processing Record 33 of Set 5 | Urmia
# Processing Record 34 of Set 5 | Dunedin
# Processing Record 35 of Set 5 | Mananara
# Processing Record 36 of Set 5 | Beaverlodge
# City not found. Skipping...
# Processing Record 37 of Set 5 | Dinguiraye
# Processing Record 38 of Set 5 | Nanortalik
# Processing Record 39 of Set 5 | Puerto Limón
# Processing Record 40 of Set 5 | Mareeba
# Processing Record 41 of Set 5 | Labuhan
# Processing Record 42 of Set 5 | Tombouctou
# Processing Record 43 of Set 5 | Abéché
# Processing Record 44 of Set 5 | Mandalgovi
# Processing Record 45 of Set 5 | Machilipatnam
# Processing Record 46 of Set 5 | Arkhipo-Osipovka
# Processing Record 47 of Set 5 | Fortuna
# Processing Record 48 of Set 5 | Botwood
# Processing Record 49 of Set 5 | Micheweni
# Processing Record 50 of Set 5 | Esim
# Processing Record 0 of Set 6 | Henties Bay
# City not found. Skipping...
# Processing Record 1 of Set 6 | Goba
# Processing Record 2 of Set 6 | São Filipe
# Processing Record 3 of Set 6 | Nizhnyaya Omka
# Processing Record 4 of Set 6 | Matamoros
# Processing Record 5 of Set 6 | Hilo
# Processing Record 6 of Set 6 | Polahongon
# Processing Record 7 of Set 6 | Banda Aceh
# Processing Record 8 of Set 6 | Wencheng
# Processing Record 9 of Set 6 | Salalah
# Processing Record 10 of Set 6 | Amasya Province
# Processing Record 11 of Set 6 | Nurota
# Processing Record 12 of Set 6 | Pleasanton
# Processing Record 13 of Set 6 | Tīkamgarh
# Processing Record 14 of Set 6 | Kavieng
# City not found. Skipping...
# Processing Record 15 of Set 6 | Broome
# Processing Record 16 of Set 6 | Gunjur
# Processing Record 17 of Set 6 | Harper
# Processing Record 18 of Set 6 | Leshukonskoye
# Processing Record 19 of Set 6 | Qaqortoq
# Processing Record 20 of Set 6 | Kempele
# Processing Record 21 of Set 6 | Byron Bay
# Processing Record 22 of Set 6 | Safi
# Processing Record 23 of Set 6 | Lovozero
# City not found. Skipping...
# Processing Record 24 of Set 6 | Kaeo
# Processing Record 25 of Set 6 | Pitiquito
# Processing Record 26 of Set 6 | Zaysan
# Processing Record 27 of Set 6 | Samarai
# Processing Record 28 of Set 6 | Sisimiut
# Processing Record 29 of Set 6 | Biltine
# Processing Record 30 of Set 6 | Ridgecrest
# Processing Record 31 of Set 6 | Yeniseysk
# Processing Record 32 of Set 6 | Anadyr
# Processing Record 33 of Set 6 | Shingū
# Processing Record 34 of Set 6 | Acapulco de Juárez
# Processing Record 35 of Set 6 | Kalamb
# Processing Record 36 of Set 6 | Kaitangata
# City not found. Skipping...
# Processing Record 16 of Set 9 | Coahuayana Viejo
# Processing Record 17 of Set 9 | Ndélé
# Processing Record 18 of Set 9 | Lincoln
# Processing Record 19 of Set 9 | Griffith
# Processing Record 20 of Set 9 | Inhambane
# Processing Record 21 of Set 9 | Pombas
# Processing Record 22 of Set 9 | Rafaela
# Processing Record 23 of Set 9 | Ubari
# Processing Record 24 of Set 9 | Sheridan
# Processing Record 25 of Set 9 | Machinga
# Processing Record 26 of Set 9 | Goiatuba
# Processing Record 27 of Set 9 | Casablanca
# City not found. Skipping...
# Processing Record 28 of Set 9 | Esperança
# Processing Record 29 of Set 9 | Taseyevo
# Processing Record 30 of Set 9 | Nishihara
# Processing Record 31 of Set 9 | Nyurba
# City not found. Skipping...
# Processing Record 32 of Set 9 | Mount Isa
# Processing Record 33 of Set 9 | Srīvardhan
# Processing Record 34 of Set 9 | Raudeberg
# City not found. Skipping...
# Processing Record 35 of Set 9 | Santa Ana
# City not found. Skipping...
# Processing Record 36 of Set 9 | Bad Salzungen
# Processing Record 37 of Set 9 | Buraidah
# Processing Record 38 of Set 9 | Mezen'
# Processing Record 39 of Set 9 | Aklavik
# Processing Record 40 of Set 9 | Kisangani
# Processing Record 41 of Set 9 | Santa Isabel
# Processing Record 42 of Set 9 | Sakurai
# Processing Record 43 of Set 9 | Hanzhong
# Processing Record 44 of Set 9 | Sangar
# Processing Record 45 of Set 9 | Thinadhoo
# Processing Record 46 of Set 9 | Ganløse
# Processing Record 47 of Set 9 | Båtsfjord
# Processing Record 48 of Set 9 | Agüimes
# Processing Record 49 of Set 9 | San Cristobal
# Processing Record 50 of Set 9 | Panabá
# Processing Record 0 of Set 10 | Skjervøy
# Processing Record 1 of Set 10 | Lososina
# Processing Record 2 of Set 10 | Vestmannaeyjar
# Processing Record 3 of Set 10 | Verkhneyarkeyevo
# Processing Record 4 of Set 10 | Omsukchan
# Processing Record 5 of Set 10 | Rosarito
# Processing Record 6 of Set 10 | Kisi
# Processing Record 7 of Set 10 | Horn Lake
# Processing Record 8 of Set 10 | Sarakhs
# Processing Record 9 of Set 10 | Sibiti
# Processing Record 10 of Set 10 | Klamath Falls
# Processing Record 11 of Set 10 | Ust-Nera
# City not found. Skipping...
# Processing Record 12 of Set 10 | Tessalit
# Processing Record 13 of Set 10 | Ajdabiya
# Processing Record 14 of Set 10 | Iroquois Falls
# City not found. Skipping...
# Processing Record 15 of Set 10 | Pudozh
# Processing Record 16 of Set 10 | Baracoa
# Processing Record 17 of Set 10 | Poronaysk
# Processing Record 18 of Set 10 | Umm Kaddadah
# Processing Record 19 of Set 10 | Palmas
# Processing Record 20 of Set 10 | Agirish
# Processing Record 21 of Set 10 | Najrān
# Processing Record 22 of Set 10 | Banfora
# Processing Record 23 of Set 10 | Koungou
# Processing Record 24 of Set 10 | Qasigiannguit
# Processing Record 25 of Set 10 | Capaci
# Processing Record 26 of Set 10 | Vredendal
# Processing Record 27 of Set 10 | Muros
# Processing Record 28 of Set 10 | Wangou
# Processing Record 29 of Set 10 | Maningrida
# Processing Record 30 of Set 10 | Verkhoyansk
# Processing Record 31 of Set 10 | Banyo
# Processing Record 32 of Set 10 | Pandamatenga
# Processing Record 33 of Set 10 | Kādīpur
# Processing Record 34 of Set 10 | South Yarmouth
# Processing Record 35 of Set 10 | Manaus
# Processing Record 36 of Set 10 | Kanniyākumāri
# Processing Record 37 of Set 10 | Oranjestad
# City not found. Skipping...
# Processing Record 38 of Set 10 | Buala
# Processing Record 39 of Set 10 | Williams Lake
# Processing Record 40 of Set 10 | Ferme-Neuve
# Processing Record 41 of Set 10 | Magadan
# Processing Record 42 of Set 10 | Novy Urengoy
# Processing Record 43 of Set 10 | Kasama
# Processing Record 44 of Set 10 | Turukhansk
# Processing Record 45 of Set 10 | Maryborough
# Processing Record 46 of Set 10 | Lompoc
# Processing Record 47 of Set 10 | Pisco
# Processing Record 48 of Set 10 | Gazojak
# Processing Record 49 of Set 10 | Aksha
# Processing Record 50 of Set 10 | Morón de la Frontera
# Processing Record 0 of Set 11 | Cabedelo
# Processing Record 1 of Set 11 | Santa Cruz del Sur
# Processing Record 2 of Set 11 | Killybegs
# Processing Record 3 of Set 11 | Copiapó
# Processing Record 4 of Set 11 | Susa
# City not found. Skipping...
# Processing Record 5 of Set 11 | Khargāpur
# Processing Record 6 of Set 11 | Paamiut
# City not found. Skipping...
# Processing Record 7 of Set 11 | Āsosa
# Processing Record 8 of Set 11 | Viedma
# Processing Record 9 of Set 11 | Winnemucca
# Processing Record 10 of Set 11 | Shimoda
# Processing Record 11 of Set 11 | Kribi
# Processing Record 12 of Set 11 | Caibarién
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 11 | Namatanai
# Processing Record 14 of Set 11 | Darhan
# City not found. Skipping...
# Processing Record 15 of Set 11 | Udachny
# Processing Record 16 of Set 11 | Kushmurun
# Processing Record 17 of Set 11 | Todos Santos
# Processing Record 18 of Set 11 | Alice Springs
# City not found. Skipping...
# Processing Record 19 of Set 11 | Mandurah
# Processing Record 20 of Set 11 | Marsh Harbour
# Processing Record 21 of Set 11 | Paita
# Processing Record 22 of Set 11 | Muborak
# Processing Record 23 of Set 11 | Kosino
# Processing Record 24 of Set 11 | Lālmohan
# Processing Record 25 of Set 11 | Nome
# Processing Record 26 of Set 11 | Constitucion
# Processing Record 27 of Set 11 | Iquique
# Processing Record 28 of Set 11 | Taos
# Processing Record 29 of Set 11 | Kiryat Shmona
# Processing Record 30 of Set 11 | Ketchikan
# Processing Record 31 of Set 11 | Klaksvík
# Processing Record 32 of Set 11 | Sobolevo
# Processing Record 33 of Set 11 | Batemans Bay
# Processing Record 34 of Set 11 | Ambilobe
# Processing Record 35 of Set 11 | Rāyagada
# Processing Record 36 of Set 11 | Klos
# City not found. Skipping...
# Processing Record 37 of Set 11 | Kieta
# Processing Record 38 of Set 11 | Bilibino
# Processing Record 39 of Set 11 | Çanakkale Province
# Processing Record 40 of Set 11 | Józefów
# Processing Record 41 of Set 11 | Lesnoy
# Processing Record 42 of Set 11 | Pathalgaon
# Processing Record 43 of Set 11 | Warri
# Processing Record 44 of Set 11 | Deputatsky
# Processing Record 45 of Set 11 | Caucayá
# Processing Record 46 of Set 11 | Olesno
# Processing Record 47 of Set 11 | Springbok
# Processing Record 48 of Set 11 | Jining
# Processing Record 49 of Set 11 | Zhigansk
# City not found. Skipping...
# Processing Record 50 of Set 11 | Tapa
# Processing Record 0 of Set 12 | Lasem
# Processing Record 1 of Set 12 | Vendôme
# Processing Record 2 of Set 12 | Quba
# Processing Record 3 of Set 12 | Lugovoy
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#View data frame to identify if data is missing
city_temp.head()
# Out:
#             City Cloudiness Country        Date Humidity      Lat       Lng  \
# 0       thompson         90      CA  1637036796       93  55.7435  -97.8558
# 1          erzin         99      RU  1637036814       69   50.261   95.1623
# 2  mar del plata         49      AR  1637036798       95 -38.0023  -57.5575
# 3          kapaa         75      US  1637036815       81  22.0752  -159.319
# 4          tiksi        100      RU  1637036815       90  71.6872  128.8694
#
#   Max Temp Wind Speed
# 0    26.76       4.61
# 1    23.67        3.8
# 2    61.09       1.99
# 3    78.78       4.61
# 4    -6.05       5.35

# %%
#Replace empty cells in data frame with "NaN" Value
city_temp[['Cloudiness','Date','Humidity','Lat','Lng','Max Temp','Wind Speed']] = city_temp[['Cloudiness','Date','Humidity','Lat','Lng','Max Temp','Wind Speed']].replace('',np.nan)
#Remove cells with "NaN" values
clean_temp = city_temp.dropna()
clean_temp.head()
# Out:
#             City  Cloudiness Country          Date  Humidity      Lat  \
# 0       thompson        90.0      CA  1.637037e+09      93.0  55.7435
# 1          erzin        99.0      RU  1.637037e+09      69.0  50.2610
# 2  mar del plata        49.0      AR  1.637037e+09      95.0 -38.0023
# 3          kapaa        75.0      US  1.637037e+09      81.0  22.0752
# 4          tiksi       100.0      RU  1.637037e+09      90.0  71.6872
#
#         Lng  Max Temp  Wind Speed
# 0  -97.8558     26.76        4.61
# 1   95.1623     23.67        3.80
# 2  -57.5575     61.09        1.99
# 3 -159.3190     78.78        4.61
# 4  128.8694     -6.05        5.35

# %%
#Import data to .csv file
clean_temp.to_csv("CityTemp.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Checking max humidity in data frame; no cities have humidity > 100%
clean_temp.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  565.000000  5.650000e+02  565.000000  565.000000  565.000000
# mean    61.076106  1.637037e+09   72.612389   19.047930   13.880107
# std     37.863082  1.263912e+02   20.613039   33.931234   88.607641
# min      0.000000  1.637037e+09    1.000000  -54.800000 -179.166700
# 25%     21.000000  1.637037e+09   62.000000   -7.844700  -63.756800
# 50%     75.000000  1.637037e+09   78.000000   20.714700   18.420900
# 75%     98.000000  1.637037e+09   88.000000   49.154100   82.383300
# max    100.000000  1.637037e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  565.000000  565.000000
# mean    55.765540    8.214619
# std     25.067257    5.767466
# min    -28.260000    0.000000
# 25%     40.080000    3.780000
# 50%     64.130000    6.910000
# 75%     75.900000   10.960000
# max     91.850000   31.210000

# %% [markdown]
# # N/A: Code that could be used to identify indices with humidity > 100

# %%
#No cities have humidity > 100%
#Filter condition can be changed to indentify indices of cities where humidity is > a specific value
index = clean_temp.index
condition = clean_temp['Humidity'] > 100
filtercondition = index[condition]
condition_list = filtercondition.tolist()

#Indices (if values exist for condition) will print below
print(condition_list)
#[] indicates no values meet condition
# Out:
# []

# %% [markdown]
# # N/A: Code that could be used to remove indices with humidity > 100

# %% [raw]
# #Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#
# #Create a new data frame; identify which indices should be removed (identified in code above)
# clean_city = clean_temp.drop(index=([xx,xx]), inplace=False)
#
# #Shows that filtered values were removed from dataframe
# index = clean_city.index
# conditions = clean_city['Humidity'] > 100
# filterconditions = index[conditions]
# condition_lists = filterconditions.tolist()
#
# #Confirms that indices including specific condition were removed; there should be no results if filtered all values
# print(condition_lists)
# clean_city.head()

# %%
clean_temp.head()
# Out:
#             City  Cloudiness Country          Date  Humidity      Lat  \
# 0       thompson        90.0      CA  1.637037e+09      93.0  55.7435
# 1          erzin        99.0      RU  1.637037e+09      69.0  50.2610
# 2  mar del plata        49.0      AR  1.637037e+09      95.0 -38.0023
# 3          kapaa        75.0      US  1.637037e+09      81.0  22.0752
# 4          tiksi       100.0      RU  1.637037e+09      90.0  71.6872
#
#         Lng  Max Temp  Wind Speed
# 0  -97.8558     26.76        4.61
# 1   95.1623     23.67        3.80
# 2  -57.5575     61.09        1.99
# 3 -159.3190     78.78        4.61
# 4  128.8694     -6.05        5.35

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_temp["Lat"]
y_values = clean_temp["Max Temp"]
plt.scatter(x_values,y_values,edgecolors='black')
plt.title(f'City Latitude vs. Max Temperature {time.strftime("%m/%d/%Y")}')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("City Latitude vs. Max Temperature.png")
plt.show(close=None)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_temp["Lat"]
y_values = clean_temp["Humidity"]
plt.scatter(x_values,y_values,edgecolors='black')
plt.title(f'City Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("City Latitude vs. Humidity.png")
plt.show(close=None)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_temp["Lat"]
y_values = clean_temp["Cloudiness"]
plt.scatter(x_values,y_values,edgecolors='black')
plt.title(f'City Latitude vs. Cloudiness {time.strftime("%m/%d/%Y")}')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("City Latitude vs. Cloudiness.png")
plt.show(close=None)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_temp["Lat"]
y_values = clean_temp["Wind Speed"]
plt.scatter(x_values,y_values,edgecolors='black')
plt.title(f'City Latitude vs. Wind Speed {time.strftime("%m/%d/%Y")}')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("City Latitude vs. Wind Speed.png")
plt.show(close=None)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create new data frame for northern hemisphere latitudes only
north_hemi = clean_temp[clean_temp['Lat'].between(0,90)]
#Confirm only northern hemisphere latitudes displayed
north_hemi.head()
# Out:
#          City  Cloudiness Country          Date  Humidity      Lat       Lng  \
# 0    thompson        90.0      CA  1.637037e+09      93.0  55.7435  -97.8558
# 1       erzin        99.0      RU  1.637037e+09      69.0  50.2610   95.1623
# 3       kapaa        75.0      US  1.637037e+09      81.0  22.0752 -159.3190
# 4       tiksi       100.0      RU  1.637037e+09      90.0  71.6872  128.8694
# 5  chokurdakh       100.0      RU  1.637037e+09      96.0  70.6333  147.9167
#
#    Max Temp  Wind Speed
# 0     26.76        4.61
# 1     23.67        3.80
# 3     78.78        4.61
# 4     -6.05        5.35
# 5      9.79        3.69

# %%
#Create new data frame for southern hemisphere latitudes only
south_hemi = clean_temp[clean_temp['Lat'].between(-90,0)]
#Confirm only southern hemisphere latitudes displayed
south_hemi.head()
# Out:
#              City  Cloudiness Country          Date  Humidity      Lat  \
# 2   mar del plata        49.0      AR  1.637037e+09      95.0 -38.0023
# 6       tuatapere       100.0      NZ  1.637037e+09      77.0 -46.1333
# 9           rundu        81.0      NA  1.637037e+09      60.0 -17.9333
# 11           cacu       100.0      BR  1.637037e+09      83.0 -18.5567
# 12   puerto ayora        40.0      EC  1.637037e+09      78.0  -0.7393
#
#          Lng  Max Temp  Wind Speed
# 2   -57.5575     61.09        1.99
# 6   167.6833     51.15        9.33
# 9    19.7667     70.02        6.20
# 11  -51.1308     72.03        9.98
# 12  -90.3518     69.30        8.39

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = north_hemi["Lat"]
y_values = north_hemi["Max Temp"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.7679558630212959

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = south_hemi["Lat"]
y_values = south_hemi["Max Temp"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.3766859599780671

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = north_hemi["Lat"]
y_values = north_hemi["Humidity"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.08809488554233272

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = south_hemi["Lat"]
y_values = south_hemi["Humidity"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.11480364191818662

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = north_hemi["Lat"]
y_values = north_hemi["Cloudiness"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,55),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.025612217224905143

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = south_hemi["Lat"]
y_values = south_hemi["Cloudiness"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.060247462558864276

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = north_hemi["Lat"]
y_values = north_hemi["Wind Speed"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.04417081162459165

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create the plot and Add the linear regression equation and line
x_values = south_hemi["Lat"]
y_values = south_hemi["Wind Speed"]

#Add slope and labels
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,21),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

#Print picture as .png
plt.savefig("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
#Print R^2 value
print(f"The r value is: {rvalue**2}")
#Show scatter plot
plt.show()
# Out:
# The r value is: 0.07420081758417425
